# %% [markdown]
# IFSC 7399
#
# Assignment 5
#
# Submitted to Prof Ningning Wu
#
# Submitted by Deepak Singla

# %% [markdown]
# # **Pandas Assignment**
#
#
# ### **Resources**
# * [Python basics Cheat Sheet](https://docs.google.com/document/d/1YcbzHos1139dSq-9DO6zYXyza1WXiBF0YdpYlG8yS1k/edit?usp=sharing)
#
# * [EDA with pandas Cheat Sheet](https://docs.google.com/document/d/1PDHUzx7dHCa6MZBpHFME8IMW3EFtcUj-FHPhi_p6QEE/edit?usp=sharing)
#
# <br>
#
# **Before starting, run the code below to import all necessary functions and libraries.**

# %%
import pandas as pd
from sklearn import datasets

# %% [markdown]
# ### **Bike Sharing Dataset in Washington, D.C.**
#
# #### **About the Dataset**
# The Bike Sharing dataset contains information about hourly bike rental data spanning two years, provided by a bike-sharing system in Washington, D.C. The dataset includes factors such as weather, date, time, and user information.
#
# **Here is information about each of the attributes:**
#
# - `instant`: A unique identifier for each record in the dataset.
#
# - `dteday`: The date of the bike rental in the format yyyy-mm-dd.
#
# - `season`: The season of the year (1: spring, 2: summer, 3: fall, 4: winter).
#
# - `yr`: The year (0: 2011, 1: 2012).
#
# - `mnth`: The month of the year (1 to 12).
#
# - `holiday`: A binary indicator of whether it is a holiday or not (0: not a holiday, 1: holiday).
#
# - `weekday`: The day of the week (0: Sunday, 1: Monday, ..., 6: Saturday).
#
# - `workingday`: A binary indicator of whether it is a working day or not (0: weekend or holiday, 1: working day).
#
# - `weathersit`: The weather situation (1: clear, 2: misty/foggy, 3: light rain/snow, 4: heavy rain/snow).
#
# - `temp`: The temperature in Celsius.
#
# - `atemp`: The "feels like" temperature in Celsius.
#
# - `hum`: The humidity level.
#
# - `windspeed`: The wind speed.
#
# - `casual`: The count of casual bike rentals.
#
# - `registered`: The count of registered bike rentals.
#
# - `cnt`: The total count of bike rentals (casual + registered).
#
#
#
# **Before continuing, run the cell below to load the DataFrame.**

# %%
# Import required libraries
import urllib.request
import zipfile

# Download the zip file and extract the CSV file(s)
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/00275/Bike-Sharing-Dataset.zip"
filename = "Bike-Sharing-Dataset.zip"
urllib.request.urlretrieve(url, filename)
with zipfile.ZipFile(filename, "r") as zip_ref:
    zip_ref.extractall()

# Read the day CSV file into a Pandas DataFrame
df = pd.read_csv("day.csv")



# Preview the first five rows of the DataFrame
df.head(5)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %% [markdown]
# ### Write Pandas code to answer following questions. You may use Python programming when needed.

# %%
#### Question 1 ####
#find column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
#### Question 2 ####
#show the last five rows in the dataset.
df.tail(5)
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 726           2  0.254167  0.226642  0.652917   0.350133     247        1867
# 727           2  0.253333  0.255046  0.590000   0.155471     644        2451
# 728           2  0.253333  0.242400  0.752917   0.124383     159        1182
# 729           1  0.255833  0.231700  0.483333   0.350754     364        1432
# 730           2  0.215833  0.223487  0.577500   0.154846     439        2290
#
#       cnt
# 726  2114
# 727  3095
# 728  1341
# 729  1796
# ...

# %%
#### Question 3 ####
#Find the number of rows and number columns in the dataset
print("Number of rows {}".format(df.shape[0]))
print("Number of columns {}".format(df.shape[1]))
# Out:
# Number of rows 731
# Number of columns 16

# %%
#### Question 4 ####
#find the number of unique values in weathersit
print("Number of unique values in weathersit {}".format(df['weathersit'].nunique()))
#df['weathersit'].nunique()
# Out:
# Number of unique values in weathersit 3

# %%
#### Question 5 ####
#What data type is the temp column?
print("Data type: {}".format(df['temp'].dtype))
# Out:
# Data type: float64

# %%
#### Question 6 ####
#group the rows by weathersit, and then find the average windspeed, temp, and cnt for each group.
df.groupby('weathersit')[['windspeed', 'temp', 'cnt']].mean()
# Out:
#             windspeed      temp          cnt
# weathersit
# 1            0.190253  0.511541  4876.786177
# 2            0.186431  0.470366  4035.862348
# 3            0.243336  0.433440  1803.285714

# %%
#### Question 7 ####
#find the percentage of bikes that are rented on weekdays

bikesRentedwholeWeek = df['cnt'].sum()

print("Bikes rented in whole week: {}".format(bikesRentedwholeWeek))

rentedOnWeekdays = df.query("weekday != 0 and weekday != 6")['cnt'].sum()

percentageOfBikesRentedOnWeekdays = (rentedOnWeekdays/bikesRentedwholeWeek) * 100

print("Percent of bikes rented on a weekdays: {}".format(percentageOfBikesRentedOnWeekdays))
# Out:
# Bikes rented in whole week: 3292679
# Percent of bikes rented on a weekdays: 72.00352661161322

# %%
#### Question 8 ####
#weathersit: The weather situation (1: clear, 2: misty/foggy, 3: light rain/snow, 4: heavy rain/snow).
#What is the average number of bikes rented during light rain/snow day?
bikesRented = df.query("weathersit == 3")['cnt'].mean()
print("Average number of bikes rented during light rain/snow day: {}".format(bikesRented))
# Out:
# Average number of bikes rented during light rain/snow day: 1803.2857142857142

# %%
#### Question 9 ####
#find  records with the row index between 20 and 25, and column index as 7, 9, and 10.
df.iloc[20:26, [7, 9, 10]]
# Out:
#     workingday      temp     atemp
# 20           1  0.177500  0.157833
# 21           0  0.059130  0.079070
# 22           0  0.096522  0.098839
# 23           1  0.097391  0.117930
# 24           1  0.223478  0.234526
# 25           1  0.217500  0.203600

# %%
#### Question 10 ####
#find the maximum windspeed recorded in the dataset
print("Max windspeed recorded in the dataset: {}".format(df['windspeed'].max()))
# Out:
# Max windspeed recorded in the dataset 0.507463

# %%
#### Question 11 ####
#find all the rows with the maximum windspeed
print("Rows with the maximum windspeed:")
df[df['windspeed'] == df['windspeed'].max()]
# Out:
# Rows with the maximum windspeed:
#     instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 49       50  2011-02-19       1   0     2        0        6           0
#
#     weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 49           1  0.399167  0.391404  0.187917   0.507463     532        1103
#
#      cnt
# 49  1635

# %%
#### Question 12 ####
#find the rows with windspeed less than the average windspeed
print("Rows with windspeed less than the average windspeed:")
df[df['windspeed'] < df['windspeed'].mean()]
# Out:
# Rows with windspeed less than the average windspeed:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 723      724  2012-12-24       1   1    12        0        1           1
# 724      725  2012-12-25       1   1    12        1        2           0
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
# ...

# %%
#### Question 13 ####
# rename columns so they are all captalized
df.columns = df.columns.str.upper()
df.head()
# Out:
#    INSTANT      DTEDAY  SEASON  YR  MNTH  HOLIDAY  WEEKDAY  WORKINGDAY  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    WEATHERSIT      TEMP     ATEMP       HUM  WINDSPEED  CASUAL  REGISTERED  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     CNT     CNT
# 0   985     NaN
# 1   801     NaN
# 2  1349     NaN
# 3  1562     NaN
# ...

# %%
#### Question 14 ####
# update the cnt of the 5th row to 1400
df.loc[4, 'CNT'] = 1400
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt     CNT
# 0   985     NaN
# 1   801     NaN
# 2  1349     NaN
# 3  1562     NaN
# ...

# %%
#### Question 15 ####
#list the rows where casual is between 800 and 1000 (inclusive).
df[(df['CASUAL'] >= 800) & (df['CASUAL'] <= 1000)]
# Out:
#      INSTANT      DTEDAY  SEASON  YR  MNTH  HOLIDAY  WEEKDAY  WORKINGDAY  \
# 71        72  2011-03-13       1   0     3        0        0           0
# 76        77  2011-03-18       1   0     3        0        5           1
# 84        85  2011-03-26       2   0     3        0        6           0
# 91        92  2011-04-02       2   0     4        0        6           0
# 98        99  2011-04-09       2   0     4        0        6           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 666      667  2012-10-28       4   1    10        0        0           0
# 687      688  2012-11-18       4   1    11        0        0           0
# 691      692  2012-11-22       4   1    11        1        4           0
# 700      701  2012-12-01       4   1    12        0        6           0
# 701      702  2012-12-02       4   1    12        0        0           0
#
#      WEATHERSIT      TEMP     ATEMP       HUM  WINDSPEED  CASUAL  REGISTERED  \
# ...

# %%
#### Question 16 ####
#delete "instant" column
df.drop('INSTANT', axis=1, inplace=True)
df.head()
# Out:
#        DTEDAY  SEASON  YR  MNTH  HOLIDAY  WEEKDAY  WORKINGDAY  WEATHERSIT  \
# 0  2011-01-01       1   0     1        0        6           0           2
# 1  2011-01-02       1   0     1        0        0           0           2
# 2  2011-01-03       1   0     1        0        1           1           1
# 3  2011-01-04       1   0     1        0        2           1           1
# 4  2011-01-05       1   0     1        0        3           1           1
#
#        TEMP     ATEMP       HUM  WINDSPEED  CASUAL  REGISTERED   CNT
# 0  0.344167  0.363625  0.805833   0.160446     331         654   985
# 1  0.363478  0.353739  0.696087   0.248539     131         670   801
# 2  0.196364  0.189405  0.437273   0.248309     120        1229  1349
# 3  0.200000  0.212122  0.590435   0.160296     108        1454  1562
# 4  0.226957  0.229270  0.436957   0.186900      82        1518  1400

# %%
#### Question 17 ####
#sort the records by cnt values in descending order.
df.sort_values('CNT', ascending=False)
# Out:
#          DTEDAY  SEASON  YR  MNTH  HOLIDAY  WEEKDAY  WORKINGDAY  WEATHERSIT  \
# 623  2012-09-15       3   1     9        0        6           0           1
# 637  2012-09-29       4   1     9        0        6           0           1
# 630  2012-09-22       3   1     9        0        6           0           1
# 447  2012-03-23       2   1     3        0        5           1           2
# 504  2012-05-19       2   1     5        0        6           0           1
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 64   2011-03-06       1   0     3        0        0           0           2
# 25   2011-01-26       1   0     1        0        3           1           3
# 725  2012-12-26       1   1    12        0        3           1           3
# 26   2011-01-27       1   0     1        0        4           1           1
# 667  2012-10-29       4   1    10        0        1           1           3
#
# ...

# %%
#### Question 18 ####
#list the rows with workingday=1 and casual>500.
df[(df['WORKINGDAY'] == 1) & (df['CASUAL'] > 500)]
# Out:
#          DTEDAY  SEASON  YR  MNTH  HOLIDAY  WEEKDAY  WORKINGDAY  WEATHERSIT  \
# 48   2011-02-18       1   0     2        0        5           1           1
# 76   2011-03-18       1   0     3        0        5           1           1
# 93   2011-04-04       2   0     4        0        1           1           1
# 96   2011-04-07       2   0     4        0        4           1           1
# 100  2011-04-11       2   0     4        0        1           1           2
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 690  2012-11-21       4   1    11        0        3           1           1
# 692  2012-11-23       4   1    11        0        5           1           1
# 702  2012-12-03       4   1    12        0        1           1           1
# 703  2012-12-04       4   1    12        0        2           1           1
# 727  2012-12-28       1   1    12        0        5           1           2
#
# ...

# %%
#### Question 19 ####
# for the rows with workingday=0 and casual<1000, list their values of temp, atemp, hum, and windspeed.
df.loc[(df['WORKINGDAY'] == 0) & (df['CASUAL'] < 1000), ['TEMP', 'ATEMP', 'HUM', 'WINDSPEED']]
# Out:
#          TEMP     ATEMP       HUM  WINDSPEED
# 0    0.344167  0.363625  0.805833   0.160446
# 1    0.363478  0.353739  0.696087   0.248539
# 7    0.165000  0.162254  0.535833   0.266804
# 8    0.138333  0.116175  0.434167   0.361950
# 14   0.233333  0.248112  0.498750   0.157963
# ..        ...       ...       ...        ...
# 721  0.265833  0.236113  0.441250   0.407346
# 722  0.245833  0.259471  0.515417   0.133083
# 724  0.291304  0.294465  0.734783   0.168726
# 728  0.253333  0.242400  0.752917   0.124383
# 729  0.255833  0.231700  0.483333   0.350754
#
# [92 rows x 4 columns]

# %%
#### Question 20 ####
# Find the number of records with workingday as 0 and 1 respectively.
df['WORKINGDAY'].value_counts()
# Out:
# WORKINGDAY
# 1    500
# 0    231
# Name: count, dtype: int64
