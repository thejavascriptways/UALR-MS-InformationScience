# %%
#Step - Import libraries required for various operations
# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats # For statistics like skewness and kurtosis

# visualizations
# %matplotlib inline
sns.set_style('darkgrid') # grid style setting other options 'whitegrid', 'dark', 'white', and 'ticks'
plt.style.use('fivethirtyeight') # Another popular style

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Optional: Display settings for pandas
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

print("Python libraries imported successfully")
# Out:
# Python libraries imported successfully

# %%
# Step - Read the data, for this project data is loaded in collab local repo
try:
    df = pd.read_csv('/content/finalProjectReportDataset.csv')
    print("Training data loaded successfully.")
    print(f"Dataset shape: {df.shape}")
except FileNotFoundError:
    print("Dataset not found. Please ensure the file is in the correct directory.")
    # Handle error or exit if the file is essential
    df = None # Set to None if loading failed
# Out:
# Training data loaded successfully.
# Dataset shape: (2197, 82)

# %%
# Step - Data Inspection
if  df is not None:
    # Display the first 5 rows
    print("\nFirst 5 rows of the dataset:")
    print(df.head())

    # Display basic information (non-null counts, data types)
    print("\nDataset Info:")
    df.info()

    # Display descriptive statistics for numerical columns
    print("\nDescriptive Statistics (Numerical Features):")
    # Include 'all' to get stats for object columns too (like count, unique, top, freq)
    print(df.describe(include='all'))

    # Check for missing values
    print("\nMissing Values:")
    print(df.isnull().sum())

    # Check for duplicate rows
    print("\nDuplicate Rows:")
    print(df.duplicated().sum())

else:
    print("\nSkipping initial inspection due to data loading issues.")
# Out:
# First 5 rows of the dataset:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0    534  531363010           20        RL          80.0      9605   Pave
# 1    803  906203120           20        RL          90.0     14684   Pave
# 2    956  916176030           20        RL           NaN     14375   Pave
# 3    460  528180130          120        RL          48.0      6472   Pave
# 4    487  528290030           80        RL          61.0      9734   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       Reg          Lvl    AllPub     Corner        Gtl      SawyerW
# 1   NaN       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2   NaN       IR1          Lvl    NoSeWa    CulDSac        Gtl       Timber
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      NridgHt
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm      1Fam      1Story             7             6
# 1        Norm        Norm      1Fam      1Story             7             7
# 2        Norm        Norm      1Fam        SLvl             6             6
# 3        Norm        Norm    TwnhsE      1Story             9             5
# 4        RRAn        Norm      1Fam        SLvl             7             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        2007            2007      Gable   CompShg      VinylSd      VinylSd
# 1        1990            1991        Hip   CompShg      HdBoard      HdBoard
# 2        1958            1958      Gable   CompShg      HdBoard      HdBoard
# 3        2008            2008        Hip   CompShg      VinylSd      VinylSd
# 4        2004            2004      Gable   CompShg      VinylSd      VinylSd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0          NaN           0.0         Gd         TA      PConc        Gd
# 1      BrkFace         234.0         Gd         TA     CBlock        Gd
# 2      BrkFace         541.0         TA         TA     CBlock        TA
# 3      BrkFace         500.0         Ex         TA      PConc        Ex
# 4          NaN           0.0         Gd         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf           0.0            Unf
# 1        TA            Mn            ALQ         485.0            BLQ
# 2        TA            No            GLQ         111.0            Rec
# 3        TA            No            Unf           0.0            Unf
# 4        TA            Mn            GLQ         241.0            Rec
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0       1218.0         1218.0    GasA         Ex           Y
# 1         177.0       1496.0         2158.0    GasA         Gd           Y
# 2         354.0        354.0          819.0    GasA         Gd           Y
# 3           0.0       1451.0         1451.0    GasA         Ex           Y
# 4         113.0         30.0          384.0    GasA         Ex           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr        1218           0                0         1218
# 1      SBrkr        2196           0                0         2196
# 2      FuseA        1344           0                0         1344
# 3      SBrkr        1456           0                0         1456
# 4      SBrkr         744         630                0         1374
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          1          1              3
# 1             0.0             0.0          2          0              3
# 2             0.0             1.0          1          0              3
# 3             0.0             0.0          2          0              2
# 4             0.0             0.0          2          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              7        Typ           1
# 2              1           Gd              7        Typ           1
# 3              1           Ex              6        Typ           1
# 4              1           Gd              7        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Detchd         2007.0           RFn          2.0
# 1           TA      Attchd         1990.0           RFn          3.0
# 2           Gd     Basment         1958.0           RFn          2.0
# 3           Gd      Attchd         2008.0           RFn          2.0
# 4          NaN     BuiltIn         2004.0           Fin          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        576.0          TA          TA           Y             0
# 1        701.0          TA          TA           Y            84
# 2        525.0          TA          TA           Y             0
# 3        539.0          TA          TA           Y           192
# 4        400.0          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0            178               0           0             0          0     NaN
# 1             70               0           0             0          0     NaN
# 2            118               0           0           233          0     NaN
# 3             42               0           0             0          0     NaN
# 4              0               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type Sale Condition  \
# 0   NaN          NaN         0        4     2009       WD          Normal
# 1   NaN          NaN         0        6     2009       WD          Normal
# 2   NaN          NaN         0        1     2009       COD        Abnorml
# 3   NaN          NaN         0        4     2009       WD          Normal
# 4   NaN          NaN         0        5     2009       WD          Normal
#
#    SalePrice
# 0     159000
# 1     271900
# 2     137500
# 3     248500
# 4     167000
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197 entries, 0 to 2196
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2197 non-null   int64
#  1   PID              2197 non-null   int64
#  2   MS SubClass      2197 non-null   int64
#  3   MS Zoning        2197 non-null   object
#  4   Lot Frontage     1835 non-null   float64
#  5   Lot Area         2197 non-null   int64
#  6   Street           2197 non-null   object
#  7   Alley            143 non-null    object
#  8   Lot Shape        2197 non-null   object
#  9   Land Contour     2197 non-null   object
#  10  Utilities        2197 non-null   object
#  11  Lot Config       2197 non-null   object
#  12  Land Slope       2197 non-null   object
#  13  Neighborhood     2197 non-null   object
#  14  Condition 1      2197 non-null   object
#  15  Condition 2      2197 non-null   object
#  16  Bldg Type        2197 non-null   object
#  17  House Style      2197 non-null   object
#  18  Overall Qual     2197 non-null   int64
#  19  Overall Cond     2197 non-null   int64
#  20  Year Built       2197 non-null   int64
#  21  Year Remod/Add   2197 non-null   int64
#  22  Roof Style       2197 non-null   object
#  23  Roof Matl        2197 non-null   object
#  24  Exterior 1st     2197 non-null   object
#  25  Exterior 2nd     2197 non-null   object
#  26  Mas Vnr Type     868 non-null    object
#  27  Mas Vnr Area     2175 non-null   float64
#  28  Exter Qual       2197 non-null   object
#  29  Exter Cond       2197 non-null   object
#  30  Foundation       2197 non-null   object
#  31  Bsmt Qual        2130 non-null   object
#  32  Bsmt Cond        2130 non-null   object
#  33  Bsmt Exposure    2128 non-null   object
#  34  BsmtFin Type 1   2130 non-null   object
#  35  BsmtFin SF 1     2196 non-null   float64
#  36  BsmtFin Type 2   2129 non-null   object
#  37  BsmtFin SF 2     2196 non-null   float64
#  38  Bsmt Unf SF      2196 non-null   float64
#  39  Total Bsmt SF    2196 non-null   float64
#  40  Heating          2197 non-null   object
#  41  Heating QC       2197 non-null   object
#  42  Central Air      2197 non-null   object
#  43  Electrical       2196 non-null   object
#  44  1st Flr SF       2197 non-null   int64
#  45  2nd Flr SF       2197 non-null   int64
#  46  Low Qual Fin SF  2197 non-null   int64
#  47  Gr Liv Area      2197 non-null   int64
#  48  Bsmt Full Bath   2196 non-null   float64
#  49  Bsmt Half Bath   2196 non-null   float64
#  50  Full Bath        2197 non-null   int64
#  51  Half Bath        2197 non-null   int64
#  52  Bedroom AbvGr    2197 non-null   int64
#  53  Kitchen AbvGr    2197 non-null   int64
#  54  Kitchen Qual     2197 non-null   object
#  55  TotRms AbvGrd    2197 non-null   int64
#  56  Functional       2197 non-null   object
#  57  Fireplaces       2197 non-null   int64
#  58  Fireplace Qu     1131 non-null   object
#  59  Garage Type      2077 non-null   object
#  60  Garage Yr Blt    2075 non-null   float64
#  61  Garage Finish    2075 non-null   object
#  62  Garage Cars      2196 non-null   float64
#  63  Garage Area      2196 non-null   float64
#  64  Garage Qual      2075 non-null   object
#  65  Garage Cond      2075 non-null   object
#  66  Paved Drive      2197 non-null   object
#  67  Wood Deck SF     2197 non-null   int64
#  68  Open Porch SF    2197 non-null   int64
#  69  Enclosed Porch   2197 non-null   int64
#  70  3Ssn Porch       2197 non-null   int64
#  71  Screen Porch     2197 non-null   int64
#  72  Pool Area        2197 non-null   int64
#  73  Pool QC          12 non-null     object
#  74  Fence            419 non-null    object
#  75  Misc Feature     80 non-null     object
#  76  Misc Val         2197 non-null   int64
#  77  Mo Sold          2197 non-null   int64
#  78  Yr Sold          2197 non-null   int64
#  79  Sale Type        2197 non-null   object
#  80  Sale Condition   2197 non-null   object
#  81  SalePrice        2197 non-null   int64
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.4+ MB
#
# Descriptive Statistics (Numerical Features):
#               Order           PID  MS SubClass MS Zoning  Lot Frontage  \
# count   2197.000000  2.197000e+03  2197.000000      2197   1835.000000
# unique          NaN           NaN          NaN         7           NaN
# top             NaN           NaN          NaN        RL           NaN
# freq            NaN           NaN          NaN      1704           NaN
# mean    1460.512517  7.127872e+08    57.064178       NaN     69.549319
# std      846.537251  1.887751e+08    42.360690       NaN     23.188224
# min        1.000000  5.263011e+08    20.000000       NaN     21.000000
# 25%      733.000000  5.284410e+08    20.000000       NaN     58.500000
# 50%     1452.000000  5.354532e+08    50.000000       NaN     69.000000
# 75%     2196.000000  9.071811e+08    70.000000       NaN     80.000000
# max     2929.000000  1.007100e+09   190.000000       NaN    313.000000
#
#              Lot Area Street Alley Lot Shape Land Contour Utilities  \
# count     2197.000000   2197   143      2197         2197      2197
# unique            NaN      2     2         4            4         3
# top               NaN   Pave  Grvl       Reg          Lvl    AllPub
# freq              NaN   2188    87      1389         1983      2194
# mean     10268.070096    NaN   NaN       NaN          NaN       NaN
# std       7975.740885    NaN   NaN       NaN          NaN       NaN
# min       1300.000000    NaN   NaN       NaN          NaN       NaN
# 25%       7500.000000    NaN   NaN       NaN          NaN       NaN
# 50%       9488.000000    NaN   NaN       NaN          NaN       NaN
# 75%      11660.000000    NaN   NaN       NaN          NaN       NaN
# max     215245.000000    NaN   NaN       NaN          NaN       NaN
#
#        Lot Config Land Slope Neighborhood Condition 1 Condition 2 Bldg Type  \
# count        2197       2197         2197        2197        2197      2197
# unique          5          3           28           9           8         5
# top        Inside        Gtl        NAmes        Norm        Norm      1Fam
# freq         1597       2091          324        1894        2175      1815
# mean          NaN        NaN          NaN         NaN         NaN       NaN
# std           NaN        NaN          NaN         NaN         NaN       NaN
# min           NaN        NaN          NaN         NaN         NaN       NaN
# 25%           NaN        NaN          NaN         NaN         NaN       NaN
# 50%           NaN        NaN          NaN         NaN         NaN       NaN
# 75%           NaN        NaN          NaN         NaN         NaN       NaN
# max           NaN        NaN          NaN         NaN         NaN       NaN
#
#        House Style  Overall Qual  Overall Cond   Year Built  Year Remod/Add  \
# count         2197   2197.000000   2197.000000  2197.000000     2197.000000
# unique           8           NaN           NaN          NaN             NaN
# top         1Story           NaN           NaN          NaN             NaN
# freq          1123           NaN           NaN          NaN             NaN
# mean           NaN      6.116523      5.552572  1972.030951     1984.781065
# std            NaN      1.429613      1.107019    30.450069       20.898245
# min            NaN      1.000000      1.000000  1872.000000     1950.000000
# 25%            NaN      5.000000      5.000000  1954.000000     1966.000000
# 50%            NaN      6.000000      5.000000  1975.000000     1994.000000
# 75%            NaN      7.000000      6.000000  2002.000000     2004.000000
# max            NaN     10.000000      9.000000  2010.000000     2010.000000
#
#        Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# count        2197      2197         2197         2197          868
# unique          6         8           16           17            4
# top         Gable   CompShg      VinylSd      VinylSd      BrkFace
# freq         1735      2166          790          782          658
# mean          NaN       NaN          NaN          NaN          NaN
# std           NaN       NaN          NaN          NaN          NaN
# min           NaN       NaN          NaN          NaN          NaN
# 25%           NaN       NaN          NaN          NaN          NaN
# 50%           NaN       NaN          NaN          NaN          NaN
# 75%           NaN       NaN          NaN          NaN          NaN
# max           NaN       NaN          NaN          NaN          NaN
#
#         Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual Bsmt Cond  \
# count    2175.000000       2197       2197       2197      2130      2130
# unique           NaN          4          5          6         5         5
# top              NaN         TA         TA      PConc        Gd        TA
# freq             NaN       1321       1922       1001       930      1970
# mean      105.101609        NaN        NaN        NaN       NaN       NaN
# std       184.897165        NaN        NaN        NaN       NaN       NaN
# min         0.000000        NaN        NaN        NaN       NaN       NaN
# 25%         0.000000        NaN        NaN        NaN       NaN       NaN
# 50%         0.000000        NaN        NaN        NaN       NaN       NaN
# 75%       166.000000        NaN        NaN        NaN       NaN       NaN
# max      1600.000000        NaN        NaN        NaN       NaN       NaN
#
#        Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# count           2128           2130   2196.000000           2129
# unique             4              6           NaN              6
# top               No            GLQ           NaN            Unf
# freq            1406            664           NaN           1871
# mean             NaN            NaN    445.502277            NaN
# std              NaN            NaN    465.845264            NaN
# min              NaN            NaN      0.000000            NaN
# 25%              NaN            NaN      0.000000            NaN
# 50%              NaN            NaN    368.000000            NaN
# 75%              NaN            NaN    739.000000            NaN
# max              NaN            NaN   5644.000000            NaN
#
#         BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC  \
# count    2196.000000  2196.000000    2196.000000    2197       2197
# unique           NaN          NaN            NaN       6          5
# top              NaN          NaN            NaN    GasA         Ex
# freq             NaN          NaN            NaN    2158       1126
# mean       49.341985   567.176685    1062.020947     NaN        NaN
# std       170.644815   445.327392     456.535482     NaN        NaN
# min         0.000000     0.000000       0.000000     NaN        NaN
# 25%         0.000000   225.750000     793.000000     NaN        NaN
# 50%         0.000000   469.500000     998.500000     NaN        NaN
# 75%         0.000000   809.250000    1338.000000     NaN        NaN
# max      1526.000000  2336.000000    6110.000000     NaN        NaN
#
#        Central Air Electrical   1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# count         2197       2196  2197.000000  2197.00000      2197.000000
# unique           2          5          NaN         NaN              NaN
# top              Y      SBrkr          NaN         NaN              NaN
# freq          2048       2020          NaN         NaN              NaN
# mean           NaN        NaN  1171.744652   331.93218         4.196632
# std            NaN        NaN   398.204596   430.76106        45.896142
# min            NaN        NaN   334.000000     0.00000         0.000000
# 25%            NaN        NaN   882.000000     0.00000         0.000000
# 50%            NaN        NaN  1097.000000     0.00000         0.000000
# 75%            NaN        NaN  1422.000000   702.00000         0.000000
# max            NaN        NaN  5095.000000  2065.00000      1064.000000
#
#         Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath    Full Bath    Half Bath  \
# count   2197.000000     2196.000000     2196.000000  2197.000000  2197.000000
# unique          NaN             NaN             NaN          NaN          NaN
# top             NaN             NaN             NaN          NaN          NaN
# freq            NaN             NaN             NaN          NaN          NaN
# mean    1507.873464        0.425774        0.063297     1.592626     0.369595
# std      511.844406        0.524958        0.249100     0.553347     0.500405
# min      334.000000        0.000000        0.000000     0.000000     0.000000
# 25%     1142.000000        0.000000        0.000000     1.000000     0.000000
# 50%     1452.000000        0.000000        0.000000     2.000000     0.000000
# 75%     1762.000000        1.000000        0.000000     2.000000     1.000000
# max     5642.000000        3.000000        2.000000     4.000000     2.000000
#
#         Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# count     2197.000000    2197.000000         2197    2197.000000       2197
# unique            NaN            NaN            5            NaN          8
# top               NaN            NaN           TA            NaN        Typ
# freq              NaN            NaN         1105            NaN       2037
# mean         2.858898       1.049158          NaN       6.470642        NaN
# std          0.834769       0.224512          NaN       1.591381        NaN
# min          0.000000       0.000000          NaN       2.000000        NaN
# 25%          2.000000       1.000000          NaN       5.000000        NaN
# 50%          3.000000       1.000000          NaN       6.000000        NaN
# 75%          3.000000       1.000000          NaN       7.000000        NaN
# max          8.000000       3.000000          NaN      15.000000        NaN
#
#          Fireplaces Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  \
# count   2197.000000         1131        2077    2075.000000          2075
# unique          NaN            5           6            NaN             3
# top             NaN           Gd      Attchd            NaN           Unf
# freq            NaN          564        1318            NaN           902
# mean       0.598999          NaN         NaN    1978.890120           NaN
# std        0.647862          NaN         NaN      25.753701           NaN
# min        0.000000          NaN         NaN    1895.000000           NaN
# 25%        0.000000          NaN         NaN    1961.000000           NaN
# 50%        1.000000          NaN         NaN    1981.000000           NaN
# 75%        1.000000          NaN         NaN    2003.000000           NaN
# max        4.000000          NaN         NaN    2207.000000           NaN
#
#         Garage Cars  Garage Area Garage Qual Garage Cond Paved Drive  \
# count   2196.000000  2196.000000        2075        2075        2197
# unique          NaN          NaN           5           5           3
# top             NaN          NaN          TA          TA           Y
# freq            NaN          NaN        1957        1993        1986
# mean       1.781876   476.715847         NaN         NaN         NaN
# std        0.762599   215.999290         NaN         NaN         NaN
# min        0.000000     0.000000         NaN         NaN         NaN
# 25%        1.000000   336.000000         NaN         NaN         NaN
# 50%        2.000000   480.000000         NaN         NaN         NaN
# 75%        2.000000   577.000000         NaN         NaN         NaN
# max        5.000000  1488.000000         NaN         NaN         NaN
#
#         Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  \
# count    2197.000000    2197.000000     2197.000000  2197.000000
# unique           NaN            NaN             NaN          NaN
# top              NaN            NaN             NaN          NaN
# freq             NaN            NaN             NaN          NaN
# mean       92.436959      48.768320       22.393719     2.361402
# std       121.422842      69.127588       62.063281    22.843004
# min         0.000000       0.000000        0.000000     0.000000
# 25%         0.000000       0.000000        0.000000     0.000000
# 50%         0.000000      28.000000        0.000000     0.000000
# 75%       168.000000      72.000000        0.000000     0.000000
# max       870.000000     742.000000      584.000000   360.000000
#
#         Screen Porch    Pool Area Pool QC  Fence Misc Feature      Misc Val  \
# count    2197.000000  2197.000000      12    419           80   2197.000000
# unique           NaN          NaN       4      4            5           NaN
# top              NaN          NaN      Gd  MnPrv         Shed           NaN
# freq             NaN          NaN       4    243           72           NaN
# mean       15.954028     2.789713     NaN    NaN          NaN     57.404188
# std        56.495484    39.991010     NaN    NaN          NaN    639.103790
# min         0.000000     0.000000     NaN    NaN          NaN      0.000000
# 25%         0.000000     0.000000     NaN    NaN          NaN      0.000000
# 50%         0.000000     0.000000     NaN    NaN          NaN      0.000000
# 75%         0.000000     0.000000     NaN    NaN          NaN      0.000000
# max       576.000000   800.000000     NaN    NaN          NaN  17000.000000
#
#             Mo Sold      Yr Sold Sale Type Sale Condition      SalePrice
# count   2197.000000  2197.000000      2197           2197    2197.000000
# unique          NaN          NaN        10              6            NaN
# top             NaN          NaN       WD          Normal            NaN
# freq            NaN          NaN      1898           1809            NaN
# mean       6.189804  2007.793810       NaN            NaN  182376.851161
# std        2.746902     1.314345       NaN            NaN   81168.157405
# min        1.000000  2006.000000       NaN            NaN   13100.000000
# 25%        4.000000  2007.000000       NaN            NaN  130000.000000
# 50%        6.000000  2008.000000       NaN            NaN  163500.000000
# 75%        8.000000  2009.000000       NaN            NaN  215000.000000
# max       12.000000  2010.000000       NaN            NaN  755000.000000

# %%
#Step - Explore the data and targetbvariable price using a histogram plot
if  df is not None:

    print(df.info())
    plt.figure(figsize=(4,2))
    sns.histplot(df)
    plt.title('Distribution of SalePrice')
    plt.xlabel('Sale Price ($)')
    plt.ylabel('Frequency')
    plt.show()
    print('finished hist')
    # Calculate and print skewness and kurtosis
    #print(f"Skewness: {df.skew():.2f}")
    #print(f"Kurtosis: {df.kurt():.2f}")
else:
    print("\nSalePrice analysis skipped.")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197 entries, 0 to 2196
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2197 non-null   int64
#  1   PID              2197 non-null   int64
#  2   MS SubClass      2197 non-null   int64
#  3   MS Zoning        2197 non-null   object
#  4   Lot Frontage     1835 non-null   float64
#  5   Lot Area         2197 non-null   int64
#  6   Street           2197 non-null   object
#  7   Alley            143 non-null    object
#  8   Lot Shape        2197 non-null   object
#  9   Land Contour     2197 non-null   object
#  10  Utilities        2197 non-null   object
#  11  Lot Config       2197 non-null   object
#  12  Land Slope       2197 non-null   object
#  13  Neighborhood     2197 non-null   object
#  14  Condition 1      2197 non-null   object
#  15  Condition 2      2197 non-null   object
#  16  Bldg Type        2197 non-null   object
#  17  House Style      2197 non-null   object
#  18  Overall Qual     2197 non-null   int64
#  19  Overall Cond     2197 non-null   int64
#  20  Year Built       2197 non-null   int64
#  21  Year Remod/Add   2197 non-null   int64
#  22  Roof Style       2197 non-null   object
#  23  Roof Matl        2197 non-null   object
#  24  Exterior 1st     2197 non-null   object
#  25  Exterior 2nd     2197 non-null   object
#  26  Mas Vnr Type     868 non-null    object
#  27  Mas Vnr Area     2175 non-null   float64
#  28  Exter Qual       2197 non-null   object
#  29  Exter Cond       2197 non-null   object
#  30  Foundation       2197 non-null   object
#  31  Bsmt Qual        2130 non-null   object
#  32  Bsmt Cond        2130 non-null   object
#  33  Bsmt Exposure    2128 non-null   object
#  34  BsmtFin Type 1   2130 non-null   object
#  35  BsmtFin SF 1     2196 non-null   float64
#  36  BsmtFin Type 2   2129 non-null   object
#  37  BsmtFin SF 2     2196 non-null   float64
#  38  Bsmt Unf SF      2196 non-null   float64
#  39  Total Bsmt SF    2196 non-null   float64
#  40  Heating          2197 non-null   object
#  41  Heating QC       2197 non-null   object
#  42  Central Air      2197 non-null   object
#  43  Electrical       2196 non-null   object
#  44  1st Flr SF       2197 non-null   int64
#  45  2nd Flr SF       2197 non-null   int64
#  46  Low Qual Fin SF  2197 non-null   int64
#  47  Gr Liv Area      2197 non-null   int64
#  48  Bsmt Full Bath   2196 non-null   float64
#  49  Bsmt Half Bath   2196 non-null   float64
#  50  Full Bath        2197 non-null   int64
#  51  Half Bath        2197 non-null   int64
#  52  Bedroom AbvGr    2197 non-null   int64
#  53  Kitchen AbvGr    2197 non-null   int64
#  54  Kitchen Qual     2197 non-null   object
#  55  TotRms AbvGrd    2197 non-null   int64
#  56  Functional       2197 non-null   object
#  57  Fireplaces       2197 non-null   int64
#  58  Fireplace Qu     1131 non-null   object
#  59  Garage Type      2077 non-null   object
#  60  Garage Yr Blt    2075 non-null   float64
#  61  Garage Finish    2075 non-null   object
#  62  Garage Cars      2196 non-null   float64
#  63  Garage Area      2196 non-null   float64
#  64  Garage Qual      2075 non-null   object
#  65  Garage Cond      2075 non-null   object
#  66  Paved Drive      2197 non-null   object
#  67  Wood Deck SF     2197 non-null   int64
#  68  Open Porch SF    2197 non-null   int64
#  69  Enclosed Porch   2197 non-null   int64
#  70  3Ssn Porch       2197 non-null   int64
#  71  Screen Porch     2197 non-null   int64
#  72  Pool Area        2197 non-null   int64
#  73  Pool QC          12 non-null     object
#  74  Fence            419 non-null    object
#  75  Misc Feature     80 non-null     object
#  76  Misc Val         2197 non-null   int64
#  77  Mo Sold          2197 non-null   int64
#  78  Yr Sold          2197 non-null   int64
#  79  Sale Type        2197 non-null   object
#  80  Sale Condition   2197 non-null   object
#  81  SalePrice        2197 non-null   int64
# dtypes: float64(11), int64(28), object(43)
# memory usage: 1.4+ MB
# None
